# %% [markdown]
# # Preprocessing Raw Data

# %%
import pandas as pd
import numpy as np

# %%
# Read the data
df_shm = pd.read_csv('../../data/raw/raw_shm.csv')
df_hgb = pd.read_csv('../../data/raw/raw_hgb.csv')
df_dll = pd.read_csv('../../data/raw/raw_lainnya.csv')

# %%
# Add column 'sertifikasi' to each dataframe
df_shm['sertifikasi'] = 'shm'
df_hgb['sertifikasi'] = 'hgb'
df_dll['sertifikasi'] = 'lainnya'

# %%
# Merged the data into one dataframe
df = pd.concat([df_shm, df_hgb, df_dll])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1370 entries, 0 to 425
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        1369 non-null   object
#  1   desc         1370 non-null   object
#  2   loc          1370 non-null   object
#  3   sertifikasi  1370 non-null   object
# dtypes: object(4)
# memory usage: 53.5+ KB

# %%
# Check duplicated data
df.duplicated().sum()
# Out:
# 60

# %%
# Check missing data
df.isnull().sum()
# Out:
# price          1
# desc           0
# loc            0
# sertifikasi    0
# dtype: int64

# %%
# Removes duplicated data and missing data
df = df.drop_duplicates().dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 425
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        1309 non-null   object
#  1   desc         1309 non-null   object
#  2   loc          1309 non-null   object
#  3   sertifikasi  1309 non-null   object
# dtypes: object(4)
# memory usage: 51.1+ KB

# %%
# Split the 'desc' column into 3 parts, 'n_bed', 'n_bath', and 'luas_bangunan' separated by '-'
df[['n_bed', 'n_bath', 'luas_bangunan']] = df['desc'].str.split('-', expand=True)

# Extract the digits from 'n_bed', 'n_bath', and 'luas bangunan'
df['n_bed'] = df['n_bed'].str.extract('(\d+)')
df['n_bath'] = df['n_bath'].str.extract('(\d+)')
df['luas_bangunan'] = df['luas_bangunan'].str.extract('(\d+)')

# Drop the 'desc' column
df = df.drop(columns=['desc'])

# %%
# Separate the 'loc' column into 2 parts, 'area', and 'city' separated by ','
df[['area', 'city']] = df['loc'].str.split(',', expand=True)

# Drop the 'loc' column
df = df.drop(columns=['loc'])

# %%
# Get the full price without the dot symbol and the 'Rp' string, trim the whitespace
df['price'] = df['price'].str.replace('.', '').str.replace('Rp', '').str.strip()
df
# Out:
#            price sertifikasi n_bed n_bath luas_bangunan                area  \
# 0     1850000000         shm     4      2           130           Jagakarsa
# 1    15500000000         shm     5      4           400            Cilandak
# 2     1500000000         shm     5      3           148        Pasar Minggu
# 3      474000000         shm     2      2            41       Tanjung Priok
# 4     1050000000         shm     4      3           150              Cakung
# ..           ...         ...   ...    ...           ...                 ...
# 421    450000000     lainnya     3      2           115              Kemang
# 422     50000000     lainnya     1      1            21          Cengkareng
# 423   1100000000     lainnya     6      6           200             Cibubur
# 424    120000000     lainnya     1      1            35    Mampang Prapatan
# 425  11000000000     lainnya     4      3           330  Pantai Indah Kapuk
#
#                  city
# 0     Jakarta Selatan
# 1     Jakarta Selatan
# 2     Jakarta Selatan
# 3       Jakarta Utara
# 4       Jakarta Timur
# ..                ...
# 421   Jakarta Selatan
# 422     Jakarta Barat
# 423     Jakarta Timur
# 424   Jakarta Selatan
# 425     Jakarta Utara
#
# [1309 rows x 7 columns]

# %%
# Get the data types of each column
df.dtypes
# Out:
# price            object
# sertifikasi      object
# n_bed            object
# n_bath           object
# luas_bangunan    object
# area             object
# city             object
# dtype: object

# %%
# Convert n_bed, n_bath, luas_bangunan, and price to int64
df['n_bed'] = df['n_bed'].astype(np.int64)
df['n_bath'] = df['n_bath'].astype(np.int64)
df['luas_bangunan'] = df['luas_bangunan'].astype(np.int64)
df['price'] = df['price'].astype(str).astype(np.int64)

# %%
df.dtypes
# Out:
# price             int64
# sertifikasi      object
# n_bed             int64
# n_bath            int64
# luas_bangunan     int64
# area             object
# city             object
# dtype: object

# %%
df
# Out:
#            price sertifikasi  n_bed  n_bath  luas_bangunan  \
# 0     1850000000         shm      4       2            130
# 1    15500000000         shm      5       4            400
# 2     1500000000         shm      5       3            148
# 3      474000000         shm      2       2             41
# 4     1050000000         shm      4       3            150
# ..           ...         ...    ...     ...            ...
# 421    450000000     lainnya      3       2            115
# 422     50000000     lainnya      1       1             21
# 423   1100000000     lainnya      6       6            200
# 424    120000000     lainnya      1       1             35
# 425  11000000000     lainnya      4       3            330
#
#                    area              city
# 0             Jagakarsa   Jakarta Selatan
# 1              Cilandak   Jakarta Selatan
# 2          Pasar Minggu   Jakarta Selatan
# 3         Tanjung Priok     Jakarta Utara
# 4                Cakung     Jakarta Timur
# ..                  ...               ...
# 421              Kemang   Jakarta Selatan
# 422          Cengkareng     Jakarta Barat
# 423             Cibubur     Jakarta Timur
# 424    Mampang Prapatan   Jakarta Selatan
# 425  Pantai Indah Kapuk     Jakarta Utara
#
# [1309 rows x 7 columns]

# %%
# Write to csv without the index
df.to_csv('../../data/processed/processed_data.csv', index=False)
